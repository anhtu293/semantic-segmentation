# %%
import os, glob
import random
from sklearn.model_selection import train_test_split
import cv2
import numpy as np
import pandas as pd
import multiprocessing
from copy import deepcopy
from sklearn.metrics import precision_recall_curve, auc
import tensorflow.keras as keras

# %%
train_df = pd.read_csv('./input/train.csv')
train_df.head()
# Out:
#           Image_Label                                      EncodedPixels
# 0    0011165.jpg_Fish  264918 937 266318 937 267718 937 269118 937 27...
# 1  0011165.jpg_Flower  1355565 1002 1356965 1002 1358365 1002 1359765...
# 2  0011165.jpg_Gravel                                                NaN
# 3   0011165.jpg_Sugar                                                NaN
# 4    002be4f.jpg_Fish  233813 878 235213 878 236613 878 238010 881 23...

# %%
train_df = train_df[~train_df['EncodedPixels'].isnull()]

# %%
train_df
# Out:
#               Image_Label                                      EncodedPixels
# 0        0011165.jpg_Fish  264918 937 266318 937 267718 937 269118 937 27...
# 1      0011165.jpg_Flower  1355565 1002 1356965 1002 1358365 1002 1359765...
# 4        002be4f.jpg_Fish  233813 878 235213 878 236613 878 238010 881 23...
# 5      002be4f.jpg_Flower  1339279 519 1340679 519 1342079 519 1343479 51...
# 7       002be4f.jpg_Sugar  67495 350 68895 350 70295 350 71695 350 73095 ...
# ...                   ...                                                ...
# 22171   ffd11b6.jpg_Sugar  1457936 458 1459336 458 1460736 458 1462136 45...
# 22175   ffd3dfb.jpg_Sugar  12891 428 14291 428 15691 428 17091 428 18491 ...
# 22177  ffd6680.jpg_Flower  1509467 305 1509773 7 1509782 2 1510867 310 15...
# 22178  ffd6680.jpg_Gravel  39728 823 41128 823 42528 823 43928 823 45328 ...
# 22181  ffea4f4.jpg_Flower  1194860 675 1196260 675 1197660 675 1199060 67...
#
# [11836 rows x 2 columns]

# %%
train_df['Image'] = train_df['Image_Label'].map(lambda x: x.split('_')[0])
train_df['Class'] = train_df['Image_Label'].map(lambda x: x.split('_')[1])

# %%
train_df
# Out:
#               Image_Label                                      EncodedPixels  \
# 0        0011165.jpg_Fish  264918 937 266318 937 267718 937 269118 937 27...
# 1      0011165.jpg_Flower  1355565 1002 1356965 1002 1358365 1002 1359765...
# 4        002be4f.jpg_Fish  233813 878 235213 878 236613 878 238010 881 23...
# 5      002be4f.jpg_Flower  1339279 519 1340679 519 1342079 519 1343479 51...
# 7       002be4f.jpg_Sugar  67495 350 68895 350 70295 350 71695 350 73095 ...
# ...                   ...                                                ...
# 22171   ffd11b6.jpg_Sugar  1457936 458 1459336 458 1460736 458 1462136 45...
# 22175   ffd3dfb.jpg_Sugar  12891 428 14291 428 15691 428 17091 428 18491 ...
# 22177  ffd6680.jpg_Flower  1509467 305 1509773 7 1509782 2 1510867 310 15...
# 22178  ffd6680.jpg_Gravel  39728 823 41128 823 42528 823 43928 823 45328 ...
# 22181  ffea4f4.jpg_Flower  1194860 675 1196260 675 1197660 675 1199060 67...
#
#              Image   Class
# 0      0011165.jpg    Fish
# 1      0011165.jpg  Flower
# 4      002be4f.jpg    Fish
# 5      002be4f.jpg  Flower
# 7      002be4f.jpg   Sugar
# ...            ...     ...
# 22171  ffd11b6.jpg   Sugar
# 22175  ffd3dfb.jpg   Sugar
# 22177  ffd6680.jpg  Flower
# 22178  ffd6680.jpg  Gravel
# 22181  ffea4f4.jpg  Flower
#
# [11836 rows x 4 columns]

# %%
classes = train_df['Class'].unique()

# %%
classes
# Out:
# array(['Fish', 'Flower', 'Sugar', 'Gravel'], dtype=object)

# %%
train_df = train_df.groupby('Image')['Class'].agg(set).reset_index()

# %%
train_df
# Out:
#             Image                  Class
# 0     0011165.jpg         {Fish, Flower}
# 1     002be4f.jpg  {Fish, Flower, Sugar}
# 2     0031ae9.jpg  {Fish, Flower, Sugar}
# 3     0035239.jpg       {Flower, Gravel}
# 4     003994e.jpg  {Fish, Sugar, Gravel}
# ...           ...                    ...
# 5541  ffcedf2.jpg                 {Fish}
# 5542  ffd11b6.jpg        {Flower, Sugar}
# 5543  ffd3dfb.jpg                {Sugar}
# 5544  ffd6680.jpg       {Flower, Gravel}
# 5545  ffea4f4.jpg               {Flower}
#
# [5546 rows x 2 columns]

# %%
for class_name in classes:
    train_df[class_name] = train_df['Class'].map(lambda x: 1 if class_name in x else 0)
train_df.head()
# Out:
#          Image                  Class  Fish  Flower  Sugar  Gravel
# 0  0011165.jpg         {Fish, Flower}     1       1      0       0
# 1  002be4f.jpg  {Fish, Flower, Sugar}     1       1      1       0
# 2  0031ae9.jpg  {Fish, Flower, Sugar}     1       1      1       0
# 3  0035239.jpg       {Flower, Gravel}     0       1      0       1
# 4  003994e.jpg  {Fish, Sugar, Gravel}     1       0      1       1

# %%
img_2_ohe_vector = {img:vec for img, vec in zip(train_df['Image'], train_df.iloc[:, 2:].values)}

# %%
img_2_ohe_vector
# Out:
# {'0011165.jpg': array([1, 1, 0, 0]),
#  '002be4f.jpg': array([1, 1, 1, 0]),
#  '0031ae9.jpg': array([1, 1, 1, 0]),
#  '0035239.jpg': array([0, 1, 0, 1]),
#  '003994e.jpg': array([1, 0, 1, 1]),
#  '00498ec.jpg': array([0, 0, 0, 1]),
#  '006bf7c.jpg': array([1, 0, 1, 0]),
#  '006c5a6.jpg': array([1, 0, 1, 0]),
#  '008233e.jpg': array([0, 0, 1, 0]),
#  '008a5ff.jpg': array([1, 0, 1, 0]),
#  '0091591.jpg': array([0, 1, 1, 1]),
#  '0095357.jpg': array([0, 0, 1, 0]),
#  '009e2f3.jpg': array([1, 0, 1, 1]),
#  '00a0954.jpg': array([0, 0, 1, 1]),
#  '00b81e1.jpg': array([0, 1, 1, 1]),
#  '00bea06.jpg': array([1, 0, 0, 1]),
#  '00cedfa.jpg': array([0, 0, 1, 1]),
#  '00d4443.jpg': array([0, 0, 1, 0]),
#  '00dec6a.jpg': array([1, 1, 1, 1]),
#  '0100a84.jpg': array([1, 0, 0, 1]),
#  '0104b5b.jpg': array([0, 0, 1, 0]),
#  '0107838.jpg': array([1, 0, 1, 1]),
#  '0118bff.jpg': array([0, 1, 1, 0]),
#  '011ba04.jpg': array([1, 1, 1, 0]),
#  '01242d7.jpg': array([1, 0, 1, 1]),
#  '014310a.jpg': array([1, 0, 1, 0]),
#  '0146ef3.jpg': array([1, 0, 0, 0]),
#  '0153a8b.jpg': array([1, 0, 1, 1]),
#  '015aa06.jpg': array([1, 1, 1, 1]),
#  '015b764.jpg': array([1, 1, 1, 0]),
#  '016c135.jpg': array([1, 0, 1, 1]),
#  '017ded1.jpg': array([1, 0, 1, 0]),
#  '0187cd7.jpg': array([0, 1, 1, 1]),
#  '01a7865.jpg': array([0, 1, 1, 1]),
#  '01c6ec3.jpg': array([0, 1, 0, 0]),
#  '01eecc1.jpg': array([1, 0, 0, 0]),
#  '0208ccf.jpg': array([0, 1, 1, 0]),
#  '021bb26.jpg': array([1, 0, 1, 0]),
#  '0225687.jpg': array([1, 1, 0, 1]),
#  '022a275.jpg': array([0, 0, 0, 1]),
#  '022d78c.jpg': array([0, 1, 0, 1]),
#  '022fd47.jpg': array([0, 0, 0, 1]),
#  '023accd.jpg': array([1, 1, 0, 1]),
#  '025ad96.jpg': array([0, 0, 0, 1]),
#  '02601cd.jpg': array([0, 1, 1, 1]),
#  '0269e9a.jpg': array([1, 1, 0, 0]),
#  '027000d.jpg': array([0, 0, 1, 1]),
#  '0277e9a.jpg': array([1, 0, 1, 1]),
#  '028fd83.jpg': array([0, 0, 1, 1]),
#  '028fe8a.jpg': array([0, 1, 1, 0]),
#  '029b861.jpg': array([1, 0, 0, 0]),
#  '02b6a5d.jpg': array([1, 0, 0, 1]),
#  '02c3e33.jpg': array([1, 0, 1, 0]),
#  '030ac75.jpg': array([1, 1, 0, 1]),
#  '031bfc5.jpg': array([1, 0, 1, 1]),
#  '0326622.jpg': array([1, 0, 1, 0]),
#  '0330f49.jpg': array([1, 0, 0, 1]),
#  '034a383.jpg': array([1, 1, 0, 0]),
#  '034ef1c.jpg': array([1, 0, 0, 0]),
#  '0358d2e.jpg': array([1, 0, 1, 0]),
#  '0362b0a.jpg': array([0, 1, 0, 0]),
#  '0365c50.jpg': array([0, 1, 1, 1]),
#  '038407e.jpg': array([0, 1, 1, 0]),
#  '03a5e35.jpg': array([1, 0, 1, 1]),
#  '03b1dc4.jpg': array([0, 0, 1, 1]),
#  '03c3906.jpg': array([1, 1, 1, 0]),
#  '03eb81a.jpg': array([1, 0, 1, 0]),
#  '03ed174.jpg': array([0, 1, 1, 1]),
#  '04029b4.jpg': array([0, 1, 1, 0]),
#  '041cc12.jpg': array([0, 1, 1, 1]),
#  '042bba1.jpg': array([1, 0, 1, 1]),
#  '042f854.jpg': array([0, 0, 1, 1]),
#  '0432314.jpg': array([1, 1, 1, 1]),
#  '0434aa4.jpg': array([0, 1, 1, 1]),
#  '043e76c.jpg': array([1, 1, 1, 1]),
#  '043fe61.jpg': array([1, 1, 1, 0]),
#  '0448942.jpg': array([1, 0, 0, 1]),
#  '044b59c.jpg': array([0, 0, 1, 0]),
#  '0451ee4.jpg': array([1, 0, 1, 1]),
#  '045e367.jpg': array([1, 0, 1, 1]),
#  '046586a.jpg': array([0, 0, 1, 0]),
#  '047be07.jpg': array([0, 1, 1, 0]),
#  '0488540.jpg': array([1, 0, 1, 1]),
#  '04920b8.jpg': array([0, 0, 1, 1]),
#  '0493d31.jpg': array([0, 0, 1, 0]),
#  '049585f.jpg': array([1, 1, 1, 1]),
#  '0499a68.jpg': array([0, 0, 1, 1]),
#  '04a4276.jpg': array([1, 1, 0, 0]),
#  '04c2acd.jpg': array([1, 1, 1, 0]),
#  '04d2879.jpg': array([0, 1, 1, 0]),
#  '04d5fe8.jpg': array([1, 0, 0, 1]),
#  '04d92ec.jpg': array([1, 1, 1, 1]),
#  '04df149.jpg': array([0, 1, 0, 1]),
#  '04f9039.jpg': array([1, 0, 1, 1]),
#  '04fddf9.jpg': array([0, 1, 0, 1]),
#  '04fe809.jpg': array([1, 0, 1, 1]),
#  '05028f9.jpg': array([0, 1, 1, 0]),
#  '0502b9e.jpg': array([0, 0, 1, 1]),
#  '0505b52.jpg': array([1, 1, 0, 0]),
#  '050937d.jpg': array([1, 0, 1, 0]),
#  '05193c8.jpg': array([0, 0, 1, 1]),
#  '053f180.jpg': array([0, 1, 0, 0]),
#  '054c1e5.jpg': array([1, 1, 1, 0]),
#  '0556b64.jpg': array([1, 0, 1, 0]),
#  '05572a2.jpg': array([0, 1, 1, 1]),
#  '055ebcb.jpg': array([0, 1, 0, 1]),
#  '0561c49.jpg': array([0, 1, 1, 1]),
#  '056b48e.jpg': array([0, 1, 1, 0]),
#  '05776fc.jpg': array([1, 1, 1, 0]),
#  '059cca2.jpg': array([0, 0, 1, 1]),
#  '059fc10.jpg': array([1, 1, 1, 0]),
#  '05a1aa8.jpg': array([1, 0, 1, 0]),
#  '05c0dfb.jpg': array([1, 0, 0, 0]),
#  '05e20ba.jpg': array([1, 0, 1, 1]),
#  '05e67a7.jpg': array([0, 0, 1, 0]),
#  '05ea471.jpg': array([0, 0, 1, 0]),
#  '05f1431.jpg': array([0, 1, 1, 0]),
#  '05f5370.jpg': array([1, 1, 1, 1]),
#  '060774a.jpg': array([0, 0, 1, 1]),
#  '060ce39.jpg': array([1, 1, 1, 0]),
#  '061cda5.jpg': array([0, 0, 1, 0]),
#  '0624fa5.jpg': array([1, 0, 0, 1]),
#  '064dd48.jpg': array([0, 0, 1, 1]),
#  '065623d.jpg': array([1, 0, 1, 1]),
#  '066c71d.jpg': array([0, 1, 0, 1]),
#  '066f427.jpg': array([0, 1, 1, 0]),
#  '06728a1.jpg': array([0, 1, 0, 0]),
#  '0686242.jpg': array([1, 1, 0, 1]),
#  '068771e.jpg': array([1, 0, 1, 1]),
#  '0687f62.jpg': array([0, 0, 0, 1]),
#  '068d881.jpg': array([0, 0, 1, 1]),
#  '06968b0.jpg': array([0, 1, 1, 0]),
#  '0697495.jpg': array([1, 0, 0, 0]),
#  '0698236.jpg': array([1, 1, 1, 1]),
#  '06b7be8.jpg': array([1, 0, 0, 0]),
#  '06b84fd.jpg': array([1, 0, 0, 1]),
#  '06d6a41.jpg': array([0, 0, 1, 0]),
#  '06e5dd6.jpg': array([1, 0, 1, 1]),
#  '06f1f1f.jpg': array([1, 0, 1, 1]),
#  '070f5c6.jpg': array([0, 1, 1, 0]),
#  '0718a60.jpg': array([0, 0, 1, 1]),
#  '071edac.jpg': array([0, 1, 0, 0]),
#  '0721695.jpg': array([1, 0, 1, 0]),
#  '072c41a.jpg': array([0, 1, 1, 1]),
#  '07358b2.jpg': array([0, 0, 1, 1]),
#  '0741fda.jpg': array([0, 1, 1, 1]),
#  '0745d08.jpg': array([0, 1, 1, 0]),
#  '07551f3.jpg': array([0, 1, 0, 1]),
#  '0761274.jpg': array([0, 1, 0, 0]),
#  '0766057.jpg': array([1, 1, 0, 0]),
#  '076de5e.jpg': array([0, 1, 0, 0]),
#  '0770f53.jpg': array([1, 1, 1, 0]),
#  '0778609.jpg': array([0, 0, 1, 0]),
#  '077bd40.jpg': array([0, 1, 0, 1]),
#  '0799206.jpg': array([0, 0, 1, 0]),
#  '079aef5.jpg': array([0, 1, 1, 0]),
#  '07c3377.jpg': array([0, 1, 0, 0]),
#  '07c5a0d.jpg': array([1, 0, 1, 1]),
#  '07c5fc9.jpg': array([1, 0, 1, 0]),
#  '07f289d.jpg': array([0, 1, 1, 0]),
#  '07f403d.jpg': array([1, 1, 1, 0]),
#  '080c004.jpg': array([1, 0, 1, 1]),
#  '0821c37.jpg': array([0, 1, 1, 0]),
#  '08329b8.jpg': array([0, 0, 1, 1]),
#  '085507c.jpg': array([1, 0, 1, 0]),
#  '0862841.jpg': array([1, 1, 1, 1]),
#  '086b4ce.jpg': array([1, 0, 0, 1]),
#  '086c226.jpg': array([0, 0, 1, 1]),
#  '0875ced.jpg': array([0, 1, 1, 0]),
#  '0879076.jpg': array([1, 0, 1, 0]),
#  '087f98b.jpg': array([0, 0, 1, 0]),
#  '08aa34b.jpg': array([1, 0, 1, 0]),
#  '08b4cfe.jpg': array([0, 0, 1, 1]),
#  '08b7a6a.jpg': array([0, 0, 1, 1]),
#  '08b9a6f.jpg': array([1, 0, 1, 0]),
#  '08e5ced.jpg': array([1, 0, 1, 1]),
#  '08ece64.jpg': array([0, 1, 1, 0]),
#  '08f255e.jpg': array([1, 0, 0, 0]),
#  '08f8226.jpg': array([0, 1, 1, 0]),
#  '08f8fe9.jpg': array([0, 1, 0, 0]),
#  '09024fd.jpg': array([0, 1, 1, 0]),
#  '090a037.jpg': array([1, 0, 1, 1]),
#  '0916eef.jpg': array([1, 0, 1, 0]),
#  '0917ffe.jpg': array([1, 1, 0, 0]),
#  '0929f85.jpg': array([0, 0, 0, 1]),
#  '09439a0.jpg': array([0, 1, 0, 1]),
#  '094e354.jpg': array([0, 0, 1, 0]),
#  '0966d21.jpg': array([0, 0, 1, 0]),
#  '0968521.jpg': array([1, 0, 1, 0]),
#  '098252b.jpg': array([1, 1, 1, 0]),
#  '098c5e0.jpg': array([1, 1, 1, 0]),
#  '09a95c4.jpg': array([1, 1, 1, 1]),
#  '09bde05.jpg': array([0, 1, 1, 0]),
#  '09bdff1.jpg': array([0, 0, 1, 1]),
#  '09c269d.jpg': array([0, 0, 1, 1]),
#  '09c64c8.jpg': array([0, 0, 1, 1]),
#  '09cf686.jpg': array([0, 1, 1, 1]),
#  '09cfd7c.jpg': array([0, 1, 1, 0]),
#  '09d0eee.jpg': array([0, 1, 0, 0]),
#  '09d3a37.jpg': array([0, 1, 0, 0]),
#  '09d567c.jpg': array([0, 1, 1, 0]),
#  '09e313c.jpg': array([0, 1, 1, 1]),
#  '09ed9b1.jpg': array([0, 1, 1, 1]),
#  '09f7f88.jpg': array([0, 0, 1, 1]),
#  '0a14f2b.jpg': array([1, 0, 1, 1]),
#  '0a1b596.jpg': array([0, 0, 1, 1]),
#  '0a20edf.jpg': array([0, 0, 0, 1]),
#  '0a21f23.jpg': array([1, 0, 1, 1]),
#  '0a3154d.jpg': array([0, 0, 1, 1]),
#  '0a380d0.jpg': array([0, 1, 0, 0]),
#  '0a421b8.jpg': array([1, 1, 0, 0]),
#  '0a44491.jpg': array([0, 1, 1, 1]),
#  '0a4657d.jpg': array([1, 1, 0, 0]),
#  '0a515e3.jpg': array([1, 0, 0, 1]),
#  '0a5d418.jpg': array([0, 1, 1, 0]),
#  '0a60891.jpg': array([0, 0, 1, 1]),
#  '0a709e6.jpg': array([1, 1, 0, 0]),
#  '0a7a247.jpg': array([1, 0, 0, 1]),
#  '0a89811.jpg': array([0, 1, 0, 1]),
#  '0a914ab.jpg': array([0, 0, 1, 0]),
#  '0a969b9.jpg': array([1, 0, 1, 1]),
#  '0a97028.jpg': array([0, 0, 1, 1]),
#  '0a99863.jpg': array([1, 1, 0, 1]),
#  '0aa2df7.jpg': array([0, 1, 0, 0]),
#  '0aaa299.jpg': array([1, 1, 0, 1]),
#  '0aaa3dd.jpg': array([1, 0, 0, 0]),
#  '0ab1fb2.jpg': array([0, 1, 1, 0]),
#  '0ab6229.jpg': array([1, 0, 1, 0]),
#  '0ac087b.jpg': array([0, 0, 1, 1]),
#  '0ac5f5c.jpg': array([0, 1, 0, 0]),
#  '0ad0a05.jpg': array([0, 1, 1, 1]),
#  '0ad3dde.jpg': array([0, 1, 1, 0]),
#  '0ad97bb.jpg': array([0, 0, 0, 1]),
#  '0ae8c34.jpg': array([1, 0, 1, 1]),
#  '0ae968e.jpg': array([1, 1, 0, 0]),
#  '0afaa7f.jpg': array([0, 0, 1, 1]),
#  '0afd5a6.jpg': array([0, 1, 0, 1]),
#  '0b10051.jpg': array([0, 1, 0, 0]),
#  '0b1dd45.jpg': array([0, 0, 1, 1]),
#  '0b265f4.jpg': array([0, 0, 1, 1]),
#  '0b32df8.jpg': array([1, 0, 1, 1]),
#  '0b3fd78.jpg': array([1, 0, 1, 0]),
#  '0b4fb36.jpg': array([0, 1, 1, 1]),
#  '0b53e2c.jpg': array([1, 1, 1, 0]),
#  '0b5a667.jpg': array([0, 1, 1, 0]),
#  '0b652e1.jpg': array([1, 0, 0, 0]),
#  '0b6e69c.jpg': array([0, 0, 1, 0]),
#  '0b80c78.jpg': array([1, 0, 1, 0]),
#  '0bb16fb.jpg': array([0, 1, 1, 0]),
#  '0bb93f0.jpg': array([0, 1, 1, 1]),
#  '0bca0fc.jpg': array([0, 1, 1, 1]),
#  '0bdb3e1.jpg': array([1, 1, 1, 1]),
#  '0be49f7.jpg': array([1, 0, 1, 0]),
#  '0bfbfc8.jpg': array([1, 0, 1, 0]),
#  '0c0e600.jpg': array([0, 0, 1, 0]),
#  '0c10e30.jpg': array([0, 1, 0, 0]),
#  '0c15f22.jpg': array([1, 1, 1, 1]),
#  '0c1d048.jpg': array([1, 1, 1, 1]),
#  '0c1e565.jpg': array([0, 1, 1, 1]),
#  '0c2a033.jpg': array([1, 0, 1, 1]),
#  '0c4cbab.jpg': array([0, 0, 1, 1]),
#  '0c4f038.jpg': array([0, 1, 1, 1]),
#  '0c64c69.jpg': array([0, 1, 1, 0]),
#  '0c76794.jpg': array([1, 0, 1, 0]),
#  '0c88342.jpg': array([1, 0, 1, 1]),
#  '0c95a41.jpg': array([1, 0, 0, 0]),
#  '0ca6ecd.jpg': array([0, 0, 1, 1]),
#  '0cabeda.jpg': array([1, 0, 1, 1]),
#  '0cad5f3.jpg': array([1, 1, 0, 1]),
#  '0cb6144.jpg': array([1, 1, 1, 1]),
#  '0cd0a7d.jpg': array([0, 0, 1, 0]),
#  '0cd556b.jpg': array([0, 1, 0, 1]),
#  '0cdffd9.jpg': array([1, 0, 1, 0]),
#  '0cf1dcc.jpg': array([1, 0, 1, 0]),
#  '0cf6773.jpg': array([0, 1, 1, 0]),
#  '0d01dad.jpg': array([1, 0, 1, 1]),
#  '0d08b24.jpg': array([0, 1, 0, 0]),
#  '0d0af9a.jpg': array([0, 0, 1, 1]),
#  '0d0b28c.jpg': array([1, 0, 1, 1]),
#  '0d0de88.jpg': array([1, 0, 1, 0]),
#  '0d24e80.jpg': array([1, 0, 0, 0]),
#  '0d38eab.jpg': array([1, 0, 1, 0]),
#  '0d56b5d.jpg': array([1, 1, 1, 1]),
#  '0d675fc.jpg': array([1, 1, 1, 0]),
#  '0d6d044.jpg': array([1, 0, 0, 0]),
#  '0d73dcc.jpg': array([0, 1, 1, 1]),
#  '0d81f99.jpg': array([1, 1, 0, 0]),
#  '0d82645.jpg': array([0, 1, 1, 0]),
#  '0d84609.jpg': array([0, 0, 1, 1]),
#  '0d90683.jpg': array([1, 0, 0, 0]),
#  '0dab774.jpg': array([1, 0, 0, 0]),
#  '0db22fe.jpg': array([1, 0, 1, 1]),
#  '0dbccb5.jpg': array([0, 1, 1, 0]),
#  '0dbe95f.jpg': array([1, 0, 0, 1]),
#  '0dc7bb3.jpg': array([0, 0, 1, 1]),
#  '0dcd917.jpg': array([1, 0, 1, 1]),
#  '0dd0c51.jpg': array([1, 0, 0, 1]),
#  '0ddf358.jpg': array([1, 0, 1, 1]),
#  '0de33f1.jpg': array([1, 0, 1, 0]),
#  '0dfbb7e.jpg': array([1, 0, 1, 1]),
#  '0e00929.jpg': array([1, 1, 0, 1]),
#  '0e2612c.jpg': array([1, 1, 0, 0]),
#  '0e26259.jpg': array([0, 1, 0, 0]),
#  '0e407e8.jpg': array([0, 1, 1, 0]),
#  '0e42958.jpg': array([0, 0, 1, 1]),
#  '0e47c4d.jpg': array([1, 1, 1, 1]),
#  '0e54437.jpg': array([1, 1, 1, 1]),
#  '0e56ffd.jpg': array([1, 0, 0, 1]),
#  '0e77759.jpg': array([0, 0, 1, 1]),
#  '0e79fa8.jpg': array([1, 0, 1, 1]),
#  '0e86f87.jpg': array([0, 1, 1, 0]),
#  '0e8c498.jpg': array([0, 0, 1, 1]),
#  '0e9c181.jpg': array([0, 0, 1, 1]),
#  '0e9deba.jpg': array([1, 0, 1, 1]),
#  '0ea56ef.jpg': array([1, 1, 1, 1]),
#  '0eb8784.jpg': array([0, 1, 1, 0]),
#  '0eba747.jpg': array([1, 0, 0, 0]),
#  '0ebb3e3.jpg': array([1, 0, 1, 1]),
#  '0ece863.jpg': array([0, 0, 1, 1]),
#  '0eecb90.jpg': array([0, 1, 1, 0]),
#  '0eee242.jpg': array([0, 0, 0, 1]),
#  '0ef0a95.jpg': array([1, 1, 0, 1]),
#  '0eff39e.jpg': array([1, 1, 1, 1]),
#  '0f1786f.jpg': array([0, 1, 0, 0]),
#  '0f1a7a3.jpg': array([0, 1, 1, 0]),
#  '0f1d18d.jpg': array([0, 1, 1, 0]),
#  '0f21e87.jpg': array([0, 0, 1, 1]),
#  '0f22465.jpg': array([1, 1, 1, 0]),
#  '0f34634.jpg': array([1, 0, 0, 1]),
#  '0f507d3.jpg': array([1, 0, 1, 1]),
#  '0f529c5.jpg': array([0, 1, 0, 0]),
#  '0f57642.jpg': array([1, 1, 0, 1]),
#  '0f5f991.jpg': array([1, 1, 1, 0]),
#  '0f6a44e.jpg': array([0, 0, 1, 1]),
#  '0f7b777.jpg': array([1, 0, 1, 1]),
#  '0f91409.jpg': array([0, 0, 0, 1]),
#  '0f9a390.jpg': array([1, 0, 0, 0]),
#  '0fa3287.jpg': array([0, 1, 1, 0]),
#  '0fb3674.jpg': array([0, 0, 1, 1]),
#  '0fb5df4.jpg': array([0, 1, 1, 1]),
#  '0fb64d9.jpg': array([0, 0, 1, 0]),
#  '0fc0e21.jpg': array([1, 1, 1, 0]),
#  '0fcf213.jpg': array([0, 0, 0, 1]),
#  '0fdf64a.jpg': array([1, 0, 0, 1]),
#  '0fe3fd9.jpg': array([0, 1, 0, 0]),
#  '0ff2c12.jpg': array([0, 1, 1, 1]),
#  '100752c.jpg': array([0, 0, 0, 1]),
#  '1007e0c.jpg': array([1, 1, 0, 0]),
#  '100bcc1.jpg': array([1, 0, 0, 0]),
#  '1013c1d.jpg': array([1, 1, 1, 0]),
#  '10192c3.jpg': array([1, 0, 1, 1]),
#  '10257e5.jpg': array([1, 0, 1, 1]),
#  '10401e7.jpg': array([1, 1, 1, 0]),
#  '1047aa1.jpg': array([1, 1, 0, 0]),
#  '104b257.jpg': array([0, 1, 0, 1]),
#  '1054bbd.jpg': array([0, 0, 1, 1]),
#  '105edca.jpg': array([1, 0, 0, 0]),
#  '106b15a.jpg': array([0, 1, 1, 0]),
#  '109a3ef.jpg': array([1, 0, 1, 1]),
#  '10bed8d.jpg': array([1, 1, 0, 0]),
#  '10c1a52.jpg': array([0, 0, 1, 1]),
#  '10cbb5e.jpg': array([0, 1, 0, 0]),
#  '10cd67c.jpg': array([1, 0, 1, 1]),
#  '10dabe8.jpg': array([0, 1, 1, 0]),
#  '10de692.jpg': array([0, 1, 1, 1]),
#  '10e475e.jpg': array([0, 1, 0, 1]),
#  '10e4ca6.jpg': array([0, 1, 0, 0]),
#  '10ed18e.jpg': array([1, 0, 1, 1]),
#  '10ed865.jpg': array([1, 0, 0, 0]),
#  '10f21b7.jpg': array([0, 0, 1, 0]),
#  '10f4f4c.jpg': array([0, 0, 1, 0]),
#  '1120e13.jpg': array([0, 0, 1, 0]),
#  '1127056.jpg': array([1, 1, 1, 0]),
#  '1130091.jpg': array([0, 0, 1, 0]),
#  '11388ad.jpg': array([0, 1, 1, 0]),
#  '1139fcf.jpg': array([0, 1, 1, 0]),
#  '1149759.jpg': array([1, 0, 1, 1]),
#  '114d48a.jpg': array([0, 1, 0, 0]),
#  '115943f.jpg': array([1, 0, 1, 1]),
#  '116433b.jpg': array([0, 1, 0, 0]),
#  '116670d.jpg': array([0, 1, 1, 1]),
#  '116afdf.jpg': array([1, 0, 1, 0]),
#  '1187ec0.jpg': array([1, 1, 0, 0]),
#  '118da86.jpg': array([0, 1, 1, 0]),
#  '11958e0.jpg': array([0, 1, 0, 0]),
#  '11c88d4.jpg': array([0, 0, 1, 1]),
#  '11e8e7b.jpg': array([1, 0, 0, 0]),
#  '11f25d7.jpg': array([0, 0, 1, 1]),
#  '11f2a0a.jpg': array([1, 1, 1, 0]),
#  '11ff032.jpg': array([0, 0, 1, 1]),
#  '121ea48.jpg': array([1, 1, 1, 1]),
#  '12252ea.jpg': array([1, 0, 0, 0]),
#  '1230c60.jpg': array([1, 1, 0, 0]),
#  '1238aa0.jpg': array([0, 1, 1, 0]),
#  '1248c99.jpg': array([1, 1, 0, 0]),
#  '124fa12.jpg': array([1, 1, 1, 0]),
#  '125ac07.jpg': array([1, 1, 1, 0]),
#  '1283aa1.jpg': array([1, 0, 1, 1]),
#  '1284dde.jpg': array([1, 1, 1, 0]),
#  '1287d3a.jpg': array([1, 1, 1, 1]),
#  '12acb4b.jpg': array([0, 1, 1, 0]),
#  '12ae62b.jpg': array([1, 0, 1, 1]),
#  '12af2d9.jpg': array([1, 1, 1, 1]),
#  '12b065b.jpg': array([0, 1, 1, 1]),
#  '12b2ee4.jpg': array([1, 1, 1, 0]),
#  '12be121.jpg': array([1, 0, 1, 1]),
#  '12be717.jpg': array([0, 1, 0, 0]),
#  '12db338.jpg': array([0, 1, 0, 0]),
#  '12e0e0d.jpg': array([1, 1, 1, 1]),
#  '12e10fa.jpg': array([1, 0, 0, 1]),
#  '12e55a8.jpg': array([0, 1, 1, 0]),
#  '12ee67e.jpg': array([1, 1, 1, 1]),
#  '12ffc06.jpg': array([0, 1, 0, 0]),
#  '1308693.jpg': array([0, 1, 1, 0]),
#  '130f074.jpg': array([0, 0, 1, 1]),
#  '1311a82.jpg': array([0, 0, 0, 1]),
#  '13123f6.jpg': array([1, 0, 1, 1]),
#  '1313e97.jpg': array([0, 0, 1, 1]),
#  '131cad7.jpg': array([0, 0, 0, 1]),
#  '131fd60.jpg': array([0, 0, 1, 0]),
#  '134d522.jpg': array([1, 1, 0, 0]),
#  '1353ca0.jpg': array([1, 0, 0, 1]),
#  '135537c.jpg': array([0, 1, 0, 0]),
#  '1355431.jpg': array([1, 0, 0, 1]),
#  '13578f2.jpg': array([0, 1, 1, 0]),
#  '135e2fa.jpg': array([0, 1, 1, 1]),
#  '1360260.jpg': array([1, 0, 1, 1]),
#  '136d170.jpg': array([1, 0, 1, 1]),
#  '136ec24.jpg': array([1, 1, 0, 1]),
#  '136f59b.jpg': array([1, 0, 1, 1]),
#  '1381cad.jpg': array([1, 1, 1, 1]),
#  '13ab789.jpg': array([0, 0, 1, 0]),
#  '13b3344.jpg': array([1, 0, 1, 0]),
#  '13c92a0.jpg': array([0, 1, 1, 1]),
#  '13cb512.jpg': array([0, 0, 0, 1]),
#  '13d35e7.jpg': array([0, 0, 1, 1]),
#  '13d3608.jpg': array([1, 1, 1, 0]),
#  '13d9125.jpg': array([0, 0, 1, 1]),
#  '13df2eb.jpg': array([0, 1, 1, 0]),
#  '13e252f.jpg': array([1, 0, 1, 0]),
#  '13eb96d.jpg': array([1, 0, 0, 0]),
#  '13fae6e.jpg': array([1, 1, 0, 0]),
#  '140c4ef.jpg': array([1, 1, 1, 1]),
#  '141a13c.jpg': array([0, 0, 1, 1]),
#  '143227b.jpg': array([1, 1, 1, 0]),
#  '143681e.jpg': array([1, 0, 1, 1]),
#  '143c7a8.jpg': array([1, 0, 1, 0]),
#  '143d3c2.jpg': array([1, 0, 0, 1]),
#  '144d107.jpg': array([0, 0, 0, 1]),
#  '144d4a8.jpg': array([0, 0, 1, 0]),
#  '146a45b.jpg': array([0, 1, 1, 1]),
#  '14750a8.jpg': array([0, 1, 1, 1]),
#  '148a6ef.jpg': array([0, 1, 0, 0]),
#  '1493053.jpg': array([1, 0, 0, 0]),
#  '14a977b.jpg': array([0, 0, 1, 0]),
#  '14aad39.jpg': array([1, 0, 0, 1]),
#  '14c052f.jpg': array([0, 0, 1, 1]),
#  '14d1403.jpg': array([1, 1, 1, 0]),
#  '14de64b.jpg': array([1, 0, 1, 0]),
#  '14df62f.jpg': array([0, 1, 1, 0]),
#  '1504549.jpg': array([0, 0, 1, 0]),
#  '15083c7.jpg': array([1, 0, 1, 1]),
#  '150c061.jpg': array([1, 0, 0, 0]),
#  '1524b90.jpg': array([1, 0, 1, 0]),
#  '15251c3.jpg': array([1, 0, 1, 0]),
#  '1525644.jpg': array([1, 0, 1, 0]),
#  '153bfaa.jpg': array([1, 1, 1, 0]),
#  '154de05.jpg': array([0, 1, 1, 1]),
#  '155f821.jpg': array([1, 1, 1, 1]),
#  '1560b44.jpg': array([0, 1, 0, 0]),
#  '1563170.jpg': array([0, 0, 1, 1]),
#  '1567149.jpg': array([0, 0, 1, 0]),
#  '156f6aa.jpg': array([0, 1, 0, 0]),
#  '15735f9.jpg': array([1, 0, 1, 0]),
#  '1584ad9.jpg': array([0, 1, 1, 1]),
#  '1588d4c.jpg': array([0, 0, 0, 1]),
#  '159985f.jpg': array([0, 1, 0, 1]),
#  '159d3a1.jpg': array([1, 0, 0, 1]),
#  '15b3f99.jpg': array([1, 0, 1, 1]),
#  '15b8121.jpg': array([0, 0, 0, 1]),
#  '15b932e.jpg': array([1, 0, 1, 0]),
#  '15b9d31.jpg': array([0, 0, 1, 1]),
#  '15d8b88.jpg': array([1, 0, 1, 1]),
#  '15d9fa0.jpg': array([0, 1, 0, 0]),
#  '15f05cb.jpg': array([1, 1, 1, 1]),
#  '160114e.jpg': array([1, 0, 0, 0]),
#  '1612248.jpg': array([0, 0, 1, 1]),
#  '161716e.jpg': array([1, 0, 1, 0]),
#  '161d598.jpg': array([1, 0, 0, 0]),
#  '1643d6e.jpg': array([0, 0, 0, 1]),
#  '1647142.jpg': array([1, 1, 1, 0]),
#  '165462c.jpg': array([1, 0, 1, 1]),
#  '166baf3.jpg': array([1, 0, 1, 0]),
#  '168f8f5.jpg': array([0, 1, 1, 0]),
#  '169a970.jpg': array([0, 0, 1, 1]),
#  '169b6b1.jpg': array([0, 0, 1, 1]),
#  '16a0d11.jpg': array([0, 0, 1, 1]),
#  '16ba64d.jpg': array([0, 0, 1, 1]),
#  '16bdc2f.jpg': array([1, 0, 1, 1]),
#  '16c5f21.jpg': array([0, 1, 0, 1]),
#  '16c65fc.jpg': array([0, 0, 1, 1]),
#  '16cf591.jpg': array([1, 0, 1, 0]),
#  '16d6983.jpg': array([1, 0, 0, 1]),
#  '16f5113.jpg': array([1, 0, 1, 1]),
#  '16f77b0.jpg': array([1, 1, 1, 1]),
#  '171e62f.jpg': array([0, 0, 1, 1]),
#  '172c0ea.jpg': array([1, 1, 1, 0]),
#  '17381cd.jpg': array([1, 1, 0, 1]),
#  '1745e62.jpg': array([0, 1, 1, 1]),
#  '174bf1a.jpg': array([1, 1, 1, 1]),
#  '175d327.jpg': array([0, 0, 1, 1]),
#  '175da8e.jpg': array([0, 1, 1, 0]),
#  '175e008.jpg': array([1, 0, 1, 1]),
#  '176650e.jpg': array([0, 0, 1, 0]),
#  '176ae6f.jpg': array([1, 0, 1, 1]),
#  '1771ac3.jpg': array([0, 0, 0, 1]),
#  '1773607.jpg': array([0, 0, 1, 1]),
#  '177cd56.jpg': array([0, 0, 1, 0]),
#  '177d1eb.jpg': array([1, 0, 0, 1]),
#  '178ceab.jpg': array([0, 0, 1, 1]),
#  '179327a.jpg': array([0, 0, 0, 1]),
#  '17a24a5.jpg': array([0, 1, 1, 1]),
#  '17a4b8a.jpg': array([0, 0, 1, 1]),
#  '17aa1aa.jpg': array([0, 0, 1, 1]),
#  '17c3776.jpg': array([1, 0, 0, 0]),
#  '17c3e51.jpg': array([0, 1, 1, 0]),
#  '17d8926.jpg': array([0, 0, 1, 0]),
#  '17e7d42.jpg': array([1, 0, 1, 1]),
#  '17f7a0b.jpg': array([0, 1, 1, 0]),
#  '17fe76e.jpg': array([1, 1, 1, 0]),
#  '17ff40b.jpg': array([1, 1, 0, 0]),
#  '180dab9.jpg': array([0, 1, 1, 1]),
#  '181395a.jpg': array([1, 1, 1, 0]),
#  '1817728.jpg': array([1, 1, 0, 1]),
#  '1818d47.jpg': array([1, 0, 1, 1]),
#  '18221ff.jpg': array([1, 0, 1, 1]),
#  '182254d.jpg': array([0, 1, 0, 0]),
#  '1822ac7.jpg': array([0, 0, 1, 1]),
#  '182409a.jpg': array([1, 1, 1, 1]),
#  '1824735.jpg': array([0, 1, 0, 0]),
#  '1827e16.jpg': array([0, 1, 1, 0]),
#  '182eb06.jpg': array([0, 0, 1, 0]),
#  '182f581.jpg': array([0, 0, 1, 1]),
#  '1837609.jpg': array([0, 0, 1, 0]),
#  '183ba8d.jpg': array([1, 0, 1, 1]),
#  '1860780.jpg': array([1, 1, 1, 0]),
#  '186b357.jpg': array([0, 0, 1, 1]),
#  '1880aa1.jpg': array([0, 1, 1, 1]),
#  '18859af.jpg': array([0, 0, 1, 0]),
#  '18a8d69.jpg': array([1, 0, 1, 0]),
#  '18c6985.jpg': array([1, 0, 1, 1]),
#  '18c9fd5.jpg': array([1, 0, 0, 1]),
#  '18d341f.jpg': array([1, 1, 0, 1]),
#  '18e7e12.jpg': array([0, 1, 1, 0]),
#  '18f4182.jpg': array([1, 0, 1, 0]),
#  '18fb01f.jpg': array([1, 0, 1, 1]),
#  '19047cf.jpg': array([1, 1, 0, 1]),
#  '1907dd8.jpg': array([1, 1, 1, 0]),
#  '1909098.jpg': array([1, 0, 1, 0]),
#  '19192fa.jpg': array([1, 0, 1, 1]),
#  '191c732.jpg': array([1, 1, 0, 1]),
#  '1930ced.jpg': array([0, 1, 0, 0]),
#  '1944d16.jpg': array([1, 1, 1, 0]),
#  '1945738.jpg': array([1, 0, 1, 1]),
#  '1945eb2.jpg': array([1, 0, 1, 1]),
#  '1955970.jpg': array([0, 1, 1, 1]),
#  '1959481.jpg': array([0, 0, 1, 0]),
#  '195f280.jpg': array([1, 0, 0, 0]),
#  '196c777.jpg': array([0, 0, 1, 1]),
#  '196f033.jpg': array([0, 0, 1, 1]),
#  '1977dc1.jpg': array([0, 1, 0, 0]),
#  '197b5b7.jpg': array([0, 0, 0, 1]),
#  '19807b1.jpg': array([1, 1, 1, 1]),
#  '198a756.jpg': array([1, 0, 0, 0]),
#  '1999872.jpg': array([1, 1, 0, 0]),
#  '19a6fb6.jpg': array([0, 0, 0, 1]),
#  '19accf7.jpg': array([1, 0, 1, 0]),
#  '19c51cd.jpg': array([1, 1, 1, 0]),
#  '19e15d2.jpg': array([0, 0, 1, 0]),
#  '19e1a35.jpg': array([1, 1, 1, 0]),
#  '19f1a0e.jpg': array([1, 1, 0, 0]),
#  '1a18d51.jpg': array([1, 1, 1, 0]),
#  '1a25aa6.jpg': array([0, 0, 1, 1]),
#  '1a296e1.jpg': array([0, 1, 0, 1]),
#  '1a3f6e6.jpg': array([1, 0, 1, 1]),
#  '1a5a7ec.jpg': array([1, 1, 1, 1]),
#  '1a5adab.jpg': array([1, 0, 0, 1]),
#  '1a69075.jpg': array([1, 0, 1, 0]),
#  '1a6a128.jpg': array([1, 1, 1, 0]),
#  '1a6bc7d.jpg': array([0, 0, 1, 1]),
#  '1a7c794.jpg': array([0, 0, 1, 1]),
#  '1a7dc3f.jpg': array([0, 0, 1, 0]),
#  '1a89fcf.jpg': array([0, 1, 1, 0]),
#  '1a96573.jpg': array([1, 1, 1, 1]),
#  '1ab3ae5.jpg': array([1, 1, 0, 1]),
#  '1ab5e0d.jpg': array([1, 0, 1, 1]),
#  '1abb599.jpg': array([0, 0, 1, 1]),
#  '1abcd7a.jpg': array([1, 0, 1, 1]),
#  '1abdd52.jpg': array([1, 0, 0, 0]),
#  '1acf4e1.jpg': array([1, 1, 0, 0]),
#  '1acf83c.jpg': array([0, 0, 1, 0]),
#  '1ad811c.jpg': array([0, 1, 0, 0]),
#  '1ae0cf9.jpg': array([1, 0, 1, 1]),
#  '1ae4549.jpg': array([1, 1, 0, 0]),
#  '1ae5c72.jpg': array([0, 0, 1, 1]),
#  '1afc3ef.jpg': array([1, 1, 1, 0]),
#  '1b0083b.jpg': array([0, 0, 1, 1]),
#  '1b0a51a.jpg': array([1, 1, 0, 0]),
#  '1b0becf.jpg': array([0, 0, 1, 1]),
#  '1b0d75f.jpg': array([0, 0, 1, 1]),
#  '1b0df6d.jpg': array([0, 1, 0, 1]),
#  '1b0faf6.jpg': array([1, 0, 1, 1]),
#  '1b15954.jpg': array([0, 1, 1, 1]),
#  '1b43606.jpg': array([1, 0, 1, 0]),
#  '1b55e5b.jpg': array([1, 0, 1, 1]),
#  '1b5a253.jpg': array([0, 1, 1, 0]),
#  '1b5e7d1.jpg': array([1, 1, 1, 0]),
#  '1b61e78.jpg': array([1, 1, 0, 1]),
#  '1b62d67.jpg': array([1, 1, 1, 0]),
#  '1b8a5c0.jpg': array([1, 0, 0, 0]),
#  '1b8c563.jpg': array([0, 0, 1, 1]),
#  '1b943b9.jpg': array([1, 0, 1, 1]),
#  '1bb252b.jpg': array([1, 0, 1, 1]),
#  '1bb3c7a.jpg': array([0, 0, 1, 1]),
#  '1bbcdab.jpg': array([1, 0, 1, 0]),
#  '1bd1af7.jpg': array([1, 0, 0, 0]),
#  '1be8360.jpg': array([0, 1, 0, 0]),
#  '1bf444c.jpg': array([1, 0, 0, 0]),
#  '1bf56de.jpg': array([1, 1, 0, 0]),
#  '1c0199e.jpg': array([0, 1, 0, 0]),
#  '1c17cd8.jpg': array([0, 1, 1, 1]),
#  '1c25e19.jpg': array([1, 1, 1, 1]),
#  '1c2a208.jpg': array([0, 0, 1, 0]),
#  '1c3a47b.jpg': array([0, 0, 1, 0]),
#  '1c4b945.jpg': array([0, 0, 1, 1]),
#  '1c51d97.jpg': array([1, 1, 1, 0]),
#  '1c5ba78.jpg': array([0, 0, 1, 1]),
#  '1c675c8.jpg': array([0, 0, 1, 0]),
#  '1c7592c.jpg': array([1, 1, 0, 0]),
#  '1c75e0f.jpg': array([0, 1, 1, 0]),
#  '1c8fab7.jpg': array([0, 1, 1, 1]),
#  '1c9c133.jpg': array([1, 0, 1, 0]),
#  '1c9dc3c.jpg': array([1, 1, 1, 1]),
#  '1ca1bf1.jpg': array([1, 0, 1, 1]),
#  '1cb3f58.jpg': array([1, 0, 0, 0]),
#  '1cc2e60.jpg': array([0, 0, 0, 1]),
#  '1ccc7db.jpg': array([1, 1, 0, 1]),
#  '1cd34f0.jpg': array([1, 1, 1, 1]),
#  '1cd4af5.jpg': array([0, 1, 1, 1]),
#  '1cd77aa.jpg': array([1, 0, 1, 1]),
#  '1d03a48.jpg': array([0, 0, 1, 0]),
#  '1d115c0.jpg': array([1, 1, 0, 1]),
#  '1d20d37.jpg': array([1, 1, 1, 1]),
#  '1d30ec2.jpg': array([1, 1, 0, 1]),
#  '1d518f2.jpg': array([0, 1, 1, 1]),
#  '1d59a74.jpg': array([1, 0, 0, 1]),
#  '1d655f7.jpg': array([0, 0, 1, 1]),
#  '1d6d628.jpg': array([1, 1, 1, 1]),
#  '1d7b9b4.jpg': array([1, 1, 0, 1]),
#  '1d8ba80.jpg': array([0, 1, 1, 0]),
#  '1d8ce67.jpg': array([0, 0, 1, 1]),
#  '1d9080c.jpg': array([1, 0, 0, 1]),
#  '1dacc16.jpg': array([0, 0, 1, 0]),
#  '1dad1e6.jpg': array([0, 0, 1, 0]),
#  '1db4de4.jpg': array([1, 0, 1, 1]),
#  '1db7e30.jpg': array([0, 1, 1, 0]),
#  '1db9078.jpg': array([1, 0, 1, 1]),
#  '1de58ae.jpg': array([0, 1, 1, 0]),
#  '1dea855.jpg': array([0, 0, 1, 0]),
#  '1df3c0f.jpg': array([0, 1, 1, 1]),
#  '1df3c2c.jpg': array([0, 0, 1, 0]),
#  '1df7c97.jpg': array([1, 0, 1, 1]),
#  '1dfdc2f.jpg': array([1, 1, 0, 0]),
#  '1e093aa.jpg': array([1, 0, 1, 1]),
#  '1e10838.jpg': array([1, 1, 1, 0]),
#  '1e128f0.jpg': array([0, 1, 0, 1]),
#  '1e40a05.jpg': array([1, 0, 0, 0]),
#  '1e40cf3.jpg': array([0, 0, 1, 1]),
#  '1e45053.jpg': array([0, 1, 1, 1]),
#  '1e53eb3.jpg': array([1, 0, 1, 1]),
#  '1e5e148.jpg': array([0, 1, 1, 0]),
#  '1e5f240.jpg': array([1, 0, 1, 0]),
#  '1e61a35.jpg': array([1, 0, 1, 0]),
#  '1e637ce.jpg': array([1, 0, 1, 0]),
#  '1e6accd.jpg': array([1, 1, 1, 1]),
#  '1e6f0a5.jpg': array([0, 1, 1, 1]),
#  '1e7e83c.jpg': array([0, 0, 1, 1]),
#  '1e81237.jpg': array([1, 1, 1, 0]),
#  '1e89fa3.jpg': array([1, 1, 0, 0]),
#  '1e9a8ba.jpg': array([0, 1, 1, 1]),
#  '1ea27d0.jpg': array([1, 0, 0, 1]),
#  '1eac7c5.jpg': array([0, 1, 1, 1]),
#  '1ec7c3e.jpg': array([0, 1, 1, 0]),
#  '1ecd287.jpg': array([0, 0, 1, 0]),
#  '1ed1c71.jpg': array([0, 0, 0, 1]),
#  '1ed1de9.jpg': array([1, 1, 0, 1]),
#  '1edcdca.jpg': array([1, 0, 1, 1]),
#  '1eee939.jpg': array([0, 1, 0, 0]),
#  '1eefbee.jpg': array([0, 1, 1, 1]),
#  '1ef6eb0.jpg': array([0, 0, 1, 1]),
#  '1efdd45.jpg': array([1, 0, 1, 1]),
#  '1f2064b.jpg': array([0, 0, 1, 1]),
#  '1f2b25e.jpg': array([1, 1, 0, 0]),
#  '1f31da9.jpg': array([0, 1, 1, 0]),
#  '1f3d231.jpg': array([0, 1, 0, 0]),
#  '1f42c22.jpg': array([0, 1, 1, 0]),
#  '1f51081.jpg': array([0, 1, 0, 1]),
#  '1f72d0c.jpg': array([0, 0, 0, 1]),
#  '1f778a1.jpg': array([1, 0, 1, 1]),
#  '1f7d39c.jpg': array([0, 0, 1, 1]),
#  '1f846aa.jpg': array([1, 1, 1, 1]),
#  '1f98b20.jpg': array([0, 0, 1, 1]),
#  '1f995ec.jpg': array([1, 1, 0, 1]),
#  '1f9dc0a.jpg': array([1, 0, 0, 0]),
#  '1f9e9c8.jpg': array([1, 0, 1, 1]),
#  '1fa1af6.jpg': array([0, 1, 0, 0]),
#  '1fa5dc9.jpg': array([1, 1, 1, 1]),
#  '1faee38.jpg': array([0, 0, 1, 1]),
#  '1fdd073.jpg': array([1, 0, 1, 0]),
#  '1fde3a9.jpg': array([0, 1, 0, 0]),
#  '1ff1606.jpg': array([1, 0, 1, 0]),
#  '1ff7088.jpg': array([1, 1, 0, 1]),
#  '1fff557.jpg': array([0, 0, 0, 1]),
#  '20019f4.jpg': array([1, 0, 1, 1]),
#  '2011ba8.jpg': array([0, 1, 0, 1]),
#  '2011d14.jpg': array([0, 1, 1, 0]),
#  '2012217.jpg': array([1, 0, 1, 0]),
#  '201e402.jpg': array([1, 1, 1, 1]),
#  '201e8bc.jpg': array([0, 1, 1, 0]),
#  '202bbe5.jpg': array([1, 1, 1, 1]),
#  '203210a.jpg': array([0, 0, 1, 1]),
#  '2034eb0.jpg': array([1, 0, 0, 0]),
#  '2052d5e.jpg': array([1, 1, 0, 0]),
#  '205f4d9.jpg': array([1, 1, 1, 0]),
#  '2072a00.jpg': array([1, 0, 1, 0]),
#  '2098442.jpg': array([1, 1, 1, 0]),
#  '20a75a2.jpg': array([1, 1, 1, 0]),
#  '20acdb9.jpg': array([0, 0, 1, 1]),
#  '20b5d9e.jpg': array([1, 0, 1, 0]),
#  '20b6edb.jpg': array([1, 0, 1, 1]),
#  '20bfa73.jpg': array([1, 0, 1, 1]),
#  '20ce8a1.jpg': array([1, 0, 0, 0]),
#  '20d18d9.jpg': array([1, 0, 1, 0]),
#  '20e355c.jpg': array([0, 1, 1, 1]),
#  '20fd60a.jpg': array([1, 1, 1, 0]),
#  '20ff5a3.jpg': array([0, 0, 0, 1]),
#  '2107837.jpg': array([1, 0, 1, 0]),
#  '2122e58.jpg': array([1, 0, 0, 0]),
#  '2146322.jpg': array([0, 1, 0, 0]),
#  '214a134.jpg': array([0, 1, 1, 1]),
#  '21561a2.jpg': array([0, 0, 0, 1]),
#  '215983c.jpg': array([0, 0, 1, 0]),
#  '217fe85.jpg': array([1, 1, 1, 0]),
#  '2181ed8.jpg': array([1, 1, 1, 0]),
#  '2184756.jpg': array([0, 1, 1, 1]),
#  '21a1772.jpg': array([1, 0, 1, 0]),
#  '21b55aa.jpg': array([0, 1, 1, 0]),
#  '21b750d.jpg': array([0, 0, 1, 0]),
#  '21d0aaf.jpg': array([0, 1, 1, 1]),
#  '21d5124.jpg': array([1, 0, 1, 0]),
#  '21d8517.jpg': array([0, 0, 1, 0]),
#  '21d93a3.jpg': array([0, 1, 0, 0]),
#  '220cb00.jpg': array([1, 0, 0, 0]),
#  '2216d4c.jpg': array([1, 1, 0, 0]),
#  '221b3c5.jpg': array([1, 0, 1, 1]),
#  '2228713.jpg': array([0, 1, 1, 1]),
#  '222adf2.jpg': array([1, 0, 0, 1]),
#  '225361c.jpg': array([1, 0, 1, 1]),
#  '226585a.jpg': array([1, 0, 0, 1]),
#  '226aec4.jpg': array([0, 0, 1, 1]),
#  '228ad71.jpg': array([0, 1, 0, 1]),
#  '22aea6f.jpg': array([1, 0, 0, 1]),
#  '22db04c.jpg': array([1, 0, 0, 1]),
#  '22eca9b.jpg': array([0, 0, 1, 0]),
#  '22ed4e2.jpg': array([1, 0, 1, 0]),
#  '2301c2f.jpg': array([1, 1, 0, 0]),
#  '23162da.jpg': array([0, 0, 1, 0]),
#  '231726b.jpg': array([0, 1, 1, 0]),
#  '2317309.jpg': array([0, 1, 1, 1]),
#  '231a6b7.jpg': array([0, 1, 1, 0]),
#  '231be51.jpg': array([1, 0, 1, 1]),
#  '231f796.jpg': array([1, 1, 1, 1]),
#  '2325bfb.jpg': array([0, 1, 0, 0]),
#  '2325e1d.jpg': array([1, 1, 1, 1]),
#  '23374cf.jpg': array([1, 0, 1, 0]),
#  '233f927.jpg': array([0, 1, 1, 1]),
#  '23565eb.jpg': array([1, 0, 0, 1]),
#  '2366810.jpg': array([0, 0, 1, 1]),
#  '237043b.jpg': array([1, 0, 1, 1]),
#  '2376acb.jpg': array([1, 0, 1, 1]),
#  '2385676.jpg': array([0, 0, 1, 1]),
#  '239d169.jpg': array([1, 1, 1, 0]),
#  '239d976.jpg': array([0, 1, 1, 0]),
#  '23a1186.jpg': array([0, 1, 1, 1]),
#  '23a172f.jpg': array([1, 0, 1, 1]),
#  '23d1c12.jpg': array([1, 1, 1, 1]),
#  '23d2127.jpg': array([0, 0, 1, 0]),
#  '23d83df.jpg': array([1, 0, 1, 1]),
#  '23e204e.jpg': array([1, 0, 1, 1]),
#  '23f4ac4.jpg': array([0, 1, 1, 0]),
#  '24005a2.jpg': array([1, 0, 0, 1]),
#  '2404bd2.jpg': array([0, 0, 1, 0]),
#  '240adca.jpg': array([0, 1, 0, 0]),
#  '240afd4.jpg': array([1, 0, 1, 1]),
#  '2416f15.jpg': array([0, 0, 1, 1]),
#  '24188a2.jpg': array([1, 0, 1, 0]),
#  '2437176.jpg': array([1, 0, 1, 0]),
#  '244894a.jpg': array([0, 1, 0, 1]),
#  '244b174.jpg': array([1, 1, 0, 1]),
#  '24681ee.jpg': array([1, 1, 0, 0]),
#  '246839b.jpg': array([0, 1, 0, 1]),
#  '2469bfe.jpg': array([0, 0, 1, 1]),
#  '247f10c.jpg': array([0, 0, 1, 0]),
#  '2485e01.jpg': array([1, 1, 1, 0]),
#  '24869a0.jpg': array([0, 0, 1, 1]),
#  '24884e7.jpg': array([0, 0, 0, 1]),
#  '248b43c.jpg': array([0, 0, 1, 0]),
#  '24afc43.jpg': array([1, 1, 0, 1]),
#  '24c16bb.jpg': array([0, 0, 0, 1]),
#  '24cf654.jpg': array([0, 0, 1, 1]),
#  '24d10e1.jpg': array([1, 0, 1, 1]),
#  '24dd99c.jpg': array([1, 1, 1, 1]),
#  '24f8df3.jpg': array([1, 0, 1, 1]),
#  '2502390.jpg': array([0, 0, 0, 1]),
#  '252418d.jpg': array([1, 1, 1, 0]),
#  '25273cd.jpg': array([0, 1, 1, 1]),
#  '25323c9.jpg': array([1, 0, 1, 1]),
#  '2537d51.jpg': array([1, 0, 1, 1]),
#  '2541bb8.jpg': array([0, 0, 1, 1]),
#  '254331b.jpg': array([1, 0, 1, 1]),
#  '25459bd.jpg': array([0, 0, 1, 1]),
#  '25496aa.jpg': array([1, 1, 1, 0]),
#  '25500bf.jpg': array([0, 0, 1, 0]),
#  '255e997.jpg': array([0, 1, 0, 0]),
#  '2567ebe.jpg': array([1, 1, 1, 1]),
#  '25771e9.jpg': array([0, 0, 1, 1]),
#  '2581372.jpg': array([0, 1, 1, 0]),
#  '2583c5d.jpg': array([0, 1, 1, 0]),
#  '259371b.jpg': array([1, 1, 0, 0]),
#  '259b3f7.jpg': array([1, 0, 1, 1]),
#  '25a0b95.jpg': array([1, 1, 0, 0]),
#  '25b508f.jpg': array([0, 1, 1, 0]),
#  '25d1550.jpg': array([1, 1, 0, 0]),
#  '25d78ce.jpg': array([0, 1, 1, 1]),
#  '25f5f23.jpg': array([1, 1, 0, 0]),
#  '25fbe3c.jpg': array([0, 0, 1, 1]),
#  '2614862.jpg': array([1, 0, 1, 1]),
#  '2637d3b.jpg': array([0, 0, 1, 1]),
#  '263ab62.jpg': array([0, 0, 1, 1]),
#  '265e050.jpg': array([0, 0, 1, 1]),
#  '26692c1.jpg': array([0, 0, 1, 1]),
#  '2670dc1.jpg': array([0, 0, 1, 0]),
#  '26848ed.jpg': array([0, 1, 1, 0]),
#  '2688104.jpg': array([0, 1, 1, 1]),
#  '26890f8.jpg': array([0, 1, 0, 1]),
#  '2689ec9.jpg': array([0, 1, 1, 0]),
#  '268bc2d.jpg': array([0, 0, 1, 1]),
#  '269a0ef.jpg': array([0, 0, 1, 1]),
#  '26a1574.jpg': array([0, 0, 1, 0]),
#  '26a3145.jpg': array([0, 1, 0, 0]),
#  '26a68cf.jpg': array([1, 0, 0, 0]),
#  '26a8ea4.jpg': array([1, 1, 1, 0]),
#  '26ab36c.jpg': array([1, 0, 1, 0]),
#  '26b05a9.jpg': array([1, 1, 0, 1]),
#  '26b5ad8.jpg': array([1, 1, 0, 0]),
#  '26b5ee8.jpg': array([0, 0, 1, 0]),
#  '26bce92.jpg': array([0, 1, 1, 0]),
#  '26bd626.jpg': array([1, 1, 1, 0]),
#  '26ca2e3.jpg': array([0, 0, 1, 0]),
#  '26d342f.jpg': array([1, 1, 0, 1]),
#  '26eea75.jpg': array([1, 1, 0, 0]),
#  '27069e6.jpg': array([1, 0, 1, 1]),
#  '270dbf3.jpg': array([1, 0, 0, 0]),
#  '271a0a9.jpg': array([0, 1, 1, 0]),
#  '273b84c.jpg': array([1, 0, 1, 0]),
#  '274bdf4.jpg': array([1, 0, 0, 0]),
#  '274bec4.jpg': array([1, 0, 0, 1]),
#  '275478e.jpg': array([1, 1, 1, 0]),
#  '2762444.jpg': array([1, 1, 1, 0]),
#  '278825d.jpg': array([1, 0, 1, 0]),
#  '27c2271.jpg': array([0, 1, 1, 0]),
#  '27cf6d3.jpg': array([1, 0, 1, 0]),
#  '27fc552.jpg': array([1, 0, 1, 1]),
#  '28084ab.jpg': array([0, 1, 1, 1]),
#  '28086d0.jpg': array([1, 0, 1, 1]),
#  '28094b7.jpg': array([1, 0, 1, 1]),
#  '280fb45.jpg': array([0, 0, 1, 0]),
#  '2828b02.jpg': array([0, 1, 0, 0]),
#  '2843f3b.jpg': array([1, 1, 1, 1]),
#  '2844251.jpg': array([1, 1, 1, 1]),
#  '286af34.jpg': array([1, 0, 1, 0]),
#  '28741bc.jpg': array([0, 1, 1, 1]),
#  '2874418.jpg': array([0, 1, 1, 0]),
#  '2882cd5.jpg': array([0, 0, 1, 0]),
#  '288bf14.jpg': array([1, 0, 0, 1]),
#  '288dea7.jpg': array([0, 1, 1, 1]),
#  '289869f.jpg': array([0, 1, 1, 0]),
#  '28a7fc0.jpg': array([1, 0, 1, 1]),
#  '28ab992.jpg': array([0, 1, 0, 0]),
#  '28b5c9d.jpg': array([0, 0, 1, 1]),
#  '28c55ac.jpg': array([1, 0, 1, 1]),
#  '28cb3b3.jpg': array([0, 1, 0, 0]),
#  '28d63a7.jpg': array([1, 1, 1, 0]),
#  '28e1750.jpg': array([0, 0, 0, 1]),
#  '28e5d9b.jpg': array([0, 1, 0, 0]),
#  '28e90ae.jpg': array([1, 0, 1, 0]),
#  '28f3277.jpg': array([0, 0, 1, 1]),
#  '2908dda.jpg': array([0, 0, 1, 1]),
#  '291a778.jpg': array([0, 1, 0, 0]),
#  '292bb4e.jpg': array([1, 0, 1, 0]),
#  '295a844.jpg': array([0, 0, 1, 1]),
#  '296636d.jpg': array([1, 0, 1, 1]),
#  '296af3d.jpg': array([0, 0, 1, 0]),
#  '297a26e.jpg': array([0, 1, 1, 0]),
#  '297af75.jpg': array([1, 0, 1, 1]),
#  '29840ba.jpg': array([1, 1, 1, 1]),
#  '298676d.jpg': array([0, 1, 0, 0]),
#  '29a268d.jpg': array([0, 1, 0, 0]),
#  '29a5a5c.jpg': array([1, 0, 0, 1]),
#  '29d9683.jpg': array([1, 0, 1, 1]),
#  '29dfbc9.jpg': array([1, 0, 1, 1]),
#  '29eebca.jpg': array([0, 0, 1, 1]),
#  '29ef385.jpg': array([1, 0, 0, 1]),
#  '29f4c4d.jpg': array([0, 1, 1, 0]),
#  '29f7bea.jpg': array([0, 1, 0, 0]),
#  '29f92e0.jpg': array([1, 1, 0, 1]),
#  '2a3950b.jpg': array([0, 0, 1, 1]),
#  '2a4bfd3.jpg': array([1, 1, 0, 0]),
#  '2a4da73.jpg': array([1, 1, 0, 1]),
#  '2a5ea2e.jpg': array([1, 1, 1, 1]),
#  '2a716ef.jpg': array([0, 0, 1, 1]),
#  '2a77bb5.jpg': array([1, 0, 0, 0]),
#  '2a7aaee.jpg': array([0, 0, 0, 1]),
#  '2a95164.jpg': array([1, 0, 1, 1]),
#  '2a9a669.jpg': array([1, 1, 1, 0]),
#  '2aa5055.jpg': array([1, 0, 1, 0]),
#  '2abbce2.jpg': array([0, 1, 1, 0]),
#  '2abd464.jpg': array([0, 1, 1, 0]),
#  '2adf501.jpg': array([1, 1, 1, 1]),
#  '2ae6637.jpg': array([0, 0, 1, 0]),
#  '2aea5d8.jpg': array([0, 0, 0, 1]),
#  '2aeac67.jpg': array([1, 1, 0, 0]),
#  '2b014d5.jpg': array([0, 1, 0, 1]),
#  '2b03476.jpg': array([1, 1, 1, 1]),
#  '2b0cded.jpg': array([0, 1, 1, 0]),
#  '2b1173c.jpg': array([1, 0, 0, 1]),
#  '2b2c1f9.jpg': array([1, 0, 1, 0]),
#  '2b335f2.jpg': array([1, 1, 0, 1]),
#  '2b48c51.jpg': array([1, 0, 0, 1]),
#  '2b48c85.jpg': array([1, 1, 0, 1]),
#  '2b51f11.jpg': array([1, 1, 0, 1]),
#  '2b53ec3.jpg': array([0, 1, 0, 0]),
#  '2b74889.jpg': array([0, 1, 0, 0]),
#  '2b76910.jpg': array([1, 0, 0, 0]),
#  '2b78c19.jpg': array([0, 1, 1, 0]),
#  '2b7f6e9.jpg': array([1, 0, 0, 0]),
#  '2b9fe8b.jpg': array([1, 0, 0, 1]),
#  '2ba1557.jpg': array([0, 1, 0, 0]),
#  '2ba6090.jpg': array([1, 1, 1, 1]),
#  '2ba7c9c.jpg': array([0, 1, 1, 0]),
#  '2bac94b.jpg': array([0, 1, 1, 1]),
#  '2bb4c59.jpg': array([1, 1, 0, 1]),
#  '2bcc55e.jpg': array([1, 1, 1, 0]),
#  '2bccb00.jpg': array([0, 0, 1, 0]),
#  '2bd2f34.jpg': array([0, 0, 1, 1]),
#  '2bdfc09.jpg': array([0, 1, 1, 1]),
#  '2bed551.jpg': array([0, 1, 1, 1]),
#  '2bee378.jpg': array([0, 0, 1, 0]),
#  '2bf9137.jpg': array([1, 0, 1, 1]),
#  '2c03f30.jpg': array([0, 0, 1, 1]),
#  '2c078e9.jpg': array([1, 0, 1, 0]),
#  '2c119c5.jpg': array([1, 0, 1, 0]),
#  '2c2d56a.jpg': array([1, 0, 0, 0]),
#  '2c50a10.jpg': array([1, 1, 1, 0]),
#  '2c69237.jpg': array([0, 0, 1, 0]),
#  '2c6b0db.jpg': array([1, 0, 0, 0]),
#  '2c799cb.jpg': array([0, 0, 1, 1]),
#  '2c85439.jpg': array([0, 0, 1, 1]),
#  '2caa0fe.jpg': array([0, 1, 0, 0]),
#  '2caaa0c.jpg': array([0, 1, 1, 0]),
#  '2ccd5bc.jpg': array([0, 0, 0, 1]),
#  '2ce15d2.jpg': array([0, 1, 1, 0]),
#  '2cf739a.jpg': array([1, 1, 1, 0]),
#  '2cfb285.jpg': array([0, 0, 1, 0]),
#  '2d04c78.jpg': array([1, 0, 0, 1]),
#  '2d09e66.jpg': array([1, 1, 1, 1]),
#  '2d13b0e.jpg': array([0, 0, 1, 1]),
#  '2d2bd73.jpg': array([0, 1, 1, 1]),
#  '2d2c35f.jpg': array([1, 0, 1, 1]),
#  '2d4a01b.jpg': array([1, 1, 0, 0]),
#  '2d505dd.jpg': array([0, 0, 1, 0]),
#  '2d5b983.jpg': array([1, 1, 0, 0]),
#  '2d6b549.jpg': array([0, 1, 0, 0]),
#  '2d6d2f2.jpg': array([0, 1, 0, 0]),
#  '2d766fa.jpg': array([0, 1, 1, 0]),
#  '2d94a62.jpg': array([1, 1, 1, 0]),
#  '2d9d608.jpg': array([0, 1, 1, 1]),
#  '2d9da73.jpg': array([0, 0, 1, 0]),
#  '2dc2879.jpg': array([1, 0, 1, 0]),
#  '2dd98b1.jpg': array([0, 0, 0, 1]),
#  ...}

# %%
train_imgs, val_imgs = train_test_split(train_df['Image'].values, 
                                        test_size=0.2, 
                                        stratify=train_df['Class'].map(lambda x: str(sorted(list(x)))), # sorting present classes in lexicographical order, just to be sure
                                        random_state=2019)

# %%
train_imgs
# Out:
# array(['a0e6825.jpg', '948a898.jpg', '4b67f58.jpg', ..., '42dca86.jpg',
#        '551efa2.jpg', '74a109d.jpg'], dtype=object)

# %%
val_imgs
# Out:
# array(['cce531c.jpg', '3e5339e.jpg', '5127b0e.jpg', ..., '265e050.jpg',
#        '9203dd2.jpg', '61aa8dc.jpg'], dtype=object)

# %%
import tensorflow.keras as keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import Sequence
from albumentations import Compose, VerticalFlip, HorizontalFlip, Rotate, GridDistortion
import matplotlib.pyplot as plt
from IPython.display import Image
from tqdm import tqdm_notebook as tqdm
from numpy.random import seed
seed(10)
import tensorflow as tf
#from tensorflow import set_random_seed
tf.random.set_seed(10)

# %%
train_imgs_folder = './input/train_images/'

# %%
class DataGenenerator(Sequence):
    def __init__(self, images_list=None, folder_imgs=train_imgs_folder, 
                 batch_size=32, shuffle=True, augmentation=None,
                 resized_height=260, resized_width=260, num_channels=3):
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.augmentation = augmentation
        if images_list is None:
            self.images_list = os.listdir(folder_imgs)
        else:
            self.images_list = deepcopy(images_list)
        self.folder_imgs = folder_imgs
        self.len = len(self.images_list) // self.batch_size
        self.resized_height = resized_height
        self.resized_width = resized_width
        self.num_channels = num_channels
        self.num_classes = 4
        self.is_test = not 'train' in folder_imgs
        if not shuffle and not self.is_test:
            self.labels = [img_2_ohe_vector[img] for img in self.images_list[:self.len*self.batch_size]]

    def __len__(self):
        return self.len
    
    def on_epoch_start(self):
        if self.shuffle:
            random.shuffle(self.images_list)

    def __getitem__(self, idx):
        current_batch = self.images_list[idx * self.batch_size: (idx + 1) * self.batch_size]
        X = np.empty((self.batch_size, self.resized_height, self.resized_width, self.num_channels))
        y = np.empty((self.batch_size, self.num_classes))

        for i, image_name in enumerate(current_batch):
            path = os.path.join(self.folder_imgs, image_name)
            img = cv2.resize(cv2.imread(path), (self.resized_height, self.resized_width)).astype(np.float32)
            if not self.augmentation is None:
                augmented = self.augmentation(image=img)
                img = augmented['image']
            X[i, :, :, :] = img/255.0
            if not self.is_test:
                y[i, :] = img_2_ohe_vector[image_name]
        return X, y

    def get_labels(self):
        if self.shuffle:
            images_current = self.images_list[:self.len*self.batch_size]
            labels = [img_2_ohe_vector[img] for img in images_current]
        else:
            labels = self.labels
        return np.array(labels)

# %%
albumentations_train = Compose([
    VerticalFlip(), HorizontalFlip(), Rotate(limit=20), GridDistortion()
], p=1)

# %%
albumentations_train
# Out:
# Compose([
#   VerticalFlip(always_apply=False, p=0.5),
#   HorizontalFlip(always_apply=False, p=0.5),
#   Rotate(always_apply=False, p=0.5, limit=(-20, 20), interpolation=1, border_mode=4, value=None, mask_value=None),
#   GridDistortion(always_apply=False, p=0.5, num_steps=5, distort_limit=(-0.3, 0.3), interpolation=1, border_mode=4, value=None, mask_value=None),
# ], p=1, bbox_params=None, keypoint_params=None, additional_targets={})

# %%
data_generator_train = DataGenenerator(train_imgs, augmentation=albumentations_train)

# %%
data_generator_train

# %%
data_generator_train_eval = DataGenenerator(train_imgs, shuffle=False)
data_generator_val = DataGenenerator(val_imgs, shuffle=False)

# %%
data_generator_train_eval

# %%
data_generator_val

# %%
class PrAucCallback(Callback):
    def __init__(self, data_generator, num_workers=num_cores, 
                 early_stopping_patience=5, 
                 plateau_patience=3, reduction_rate=0.5,
                 stage='train', checkpoints_path='checkpoints/'):
        super(Callback, self).__init__()
        self.data_generator = data_generator
        self.num_workers = num_workers
        self.class_names = ['Fish', 'Flower', 'Sugar', 'Gravel']
        self.history = [[] for _ in range(len(self.class_names) + 1)] # to store per each class and also mean PR AUC
        self.early_stopping_patience = early_stopping_patience
        self.plateau_patience = plateau_patience
        self.reduction_rate = reduction_rate
        self.stage = stage
        self.best_pr_auc = -float('inf')
        if not os.path.exists(checkpoints_path):
            os.makedirs(checkpoints_path)
        self.checkpoints_path = checkpoints_path
        
    def compute_pr_auc(self, y_true, y_pred):
        pr_auc_mean = 0
        print(f"\n{'#'*30}\n")
        for class_i in range(len(self.class_names)):
            precision, recall, _ = precision_recall_curve(y_true[:, class_i], y_pred[:, class_i])
            pr_auc = auc(recall, precision)
            pr_auc_mean += pr_auc/len(self.class_names)
            print(f"PR AUC {self.class_names[class_i]}, {self.stage}: {pr_auc:.3f}\n")
            self.history[class_i].append(pr_auc)        
        print(f"\n{'#'*20}\n PR AUC mean, {self.stage}: {pr_auc_mean:.3f}\n{'#'*20}\n")
        self.history[-1].append(pr_auc_mean)
        return pr_auc_mean
              
    def is_patience_lost(self, patience):
        if len(self.history[-1]) > patience:
            best_performance = max(self.history[-1][-(patience + 1):-1])
            return best_performance == self.history[-1][-(patience + 1)] and best_performance >= self.history[-1][-1]    
              
    def early_stopping_check(self, pr_auc_mean):
        if self.is_patience_lost(self.early_stopping_patience):
            self.model.stop_training = True    
              
    def model_checkpoint(self, pr_auc_mean, epoch):
        if pr_auc_mean > self.best_pr_auc:
            # remove previous checkpoints to save space
            for checkpoint in glob.glob(os.path.join(self.checkpoints_path, 'classifier_epoch_*')):
                os.remove(checkpoint)
        self.best_pr_auc = pr_auc_mean
        self.model.save(os.path.join(self.checkpoints_path, f'classifier_epoch_{epoch}_val_pr_auc_{pr_auc_mean}.h5'))              
        print(f"\n{'#'*20}\nSaved new checkpoint\n{'#'*20}\n")
              
    def reduce_lr_on_plateau(self):
        if self.is_patience_lost(self.plateau_patience):
            new_lr = float(keras.backend.get_value(self.model.optimizer.lr)) * self.reduction_rate
            keras.backend.set_value(self.model.optimizer.lr, new_lr)
            print(f"\n{'#'*20}\nReduced learning rate to {new_lr}.\n{'#'*20}\n")
        
    def on_epoch_end(self, epoch, logs={}):
        y_pred = self.model.predict_generator(self.data_generator, workers=self.num_workers)
        y_true = self.data_generator.get_labels()
        # estimate AUC under precision recall curve for each class
        pr_auc_mean = self.compute_pr_auc(y_true, y_pred)
              
        if self.stage == 'val':
            # early stop after early_stopping_patience=4 epochs of no improvement in mean PR AUC
            self.early_stopping_check(pr_auc_mean)

            # save a model with the best PR AUC in validation
            self.model_checkpoint(pr_auc_mean, epoch)

            # reduce learning rate on PR AUC plateau
            self.reduce_lr_on_plateau()            
        
    def get_pr_auc_history(self):
        return self.history

# %%
test_imgs_folder = '../input/test_images/'
train_imgs_folder = '../input/train_images/'
num_cores = multiprocessing.cpu_count()

# %%
num_cores

# %%
train_metric_callback = PrAucCallback(data_generator_train_eval)
val_callback = PrAucCallback(data_generator_val, stage='val')

# %%
train_metric_callback.reduction_rate
# Out:
# 0.5

# %%
val_callback

# %%
from keras.losses import binary_crossentropy
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
pip install -U git+https://github.com/qubvel/efficientnet

# %%
from keras_radam import RAdam

# %%
def get_model():
    base_model = DenseNet121(weights='imagenet', include_top=False, pooling='avg')
    x = base_model.output
    y_pred = Dense(4, activation='sigmoid')(x)
    return Model(inputs=base_model.input, outputs=y_pred)

# %%
model = get_model()

# %%
from keras_radam import RAdam


for base_layer in model.layers[:-3]:
    base_layer.trainable = False
    
model.compile(  loss='categorical_crossentropy', metrics=['accuracy'])
history_0 = model.fit_generator(generator=data_generator_train,
                              validation_data=data_generator_val,
                              epochs=20,
                              callbacks=[train_metric_callback, val_callback],
                              workers=num_cores,
                              verbose=1
                             )
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4096ed70cb16> in <module>
#       2
#       3
# ----> 4 for base_layer in model.layers[:-3]:
#       5     base_layer.trainable = False
#       6
#
# NameError: name 'model' is not defined
